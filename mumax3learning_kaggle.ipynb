# %%
! echo "This machine runs" $(uname)
# Out:
# This machine runs Linux

# %%
# Download the mumax3 binary
# !wget https://mumax.ugent.be/mumax3-binaries/mumax3.10_linux_cuda10.1.tar.gz
# !tar -xvf mumax3.10_linux_cuda10.1.tar.gz
# !rm mumax3.10_linux_cuda10.1.tar.gz
# !rm -rf mumax3.10 && mv mumax3.10_linux_cuda10.1 mumax3.10

#update the PATH environment variable
import os
os.environ['PATH'] += ":/content/mumax3.10"

# Download an examplary script
# !wget https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3 -O standardproblem4.mx3
# Out:
# --2025-10-20 13:53:00--  https://mumax.ugent.be/mumax3-binaries/mumax3.10_linux_cuda10.1.tar.gz
# Resolving mumax.ugent.be (mumax.ugent.be)... 157.193.40.77
# Connecting to mumax.ugent.be (mumax.ugent.be)|157.193.40.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150707207 (144M) [application/x-gzip]
# Saving to: ‘mumax3.10_linux_cuda10.1.tar.gz’
#
# mumax3.10_linux_cud 100%[===================>] 143.73M  28.7MB/s    in 5.8s
#
# 2025-10-20 13:53:07 (24.7 MB/s) - ‘mumax3.10_linux_cuda10.1.tar.gz’ saved [150707207/150707207]
#
# mumax3.10_linux_cuda10.1/
# mumax3.10_linux_cuda10.1/mumax3-server
# mumax3.10_linux_cuda10.1/lib/
# mumax3.10_linux_cuda10.1/lib/libcurand.so.10
# mumax3.10_linux_cuda10.1/lib/libcufft.so.10
# mumax3.10_linux_cuda10.1/mumax3
# mumax3.10_linux_cuda10.1/LICENSE
# mumax3.10_linux_cuda10.1/mumax3-convert
# --2025-10-20 13:53:09--  https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3
# ...

# %%
# !/kaggle/working/mumax3.10/mumax3 /kaggle/working/standardproblem4.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/standardproblem4.out/
# //starting GUI at http://127.0.0.1:35367
# SetGridsize(128, 32, 1)
# SetCellsize(500e-9/128, 125e-9/32, 3e-9)
# Msat = 800e3
# Aex = 13e-12
# alpha = 0.02
# m = uniform(1, .1, 0)
# relax()
# //Did not use cached kernel: open /tmp/mumax3kernel_[128 32 1]_[0 0 0]_[3.90625e-09 3.90625e-09 3e-09]_6_0 0.ovf: no such file or directory
# // Calculating demag kernel 1 %
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/bench.mx3 -O bench.mx3
# Out:
# --2025-10-20 13:59:11--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/bench.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 487 [text/plain]
# Saving to: ‘bench.mx3’
#
# bench.mx3           100%[===================>]     487  --.-KB/s    in 0s
#
# 2025-10-20 13:59:11 (25.0 MB/s) - ‘bench.mx3’ saved [487/487]

# %%
# !/kaggle/working/mumax3.10/mumax3 /kaggle/working/bench.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/bench.out/
# //starting GUI at http://127.0.0.1:35367
# msat = 800e3
# aex = 13e-12
# alpha = 0.01
# c := 4e-9
# setcellsize(c, c, c)
# setsolver(2)
# for e := 5; e < 14; e++ {
# 	n := pow(2, e)
# 	setgridsize(n, n, 1)
# 	print(n, "x", n)
# 	steps(1)
# 	b_ext = vector(0, 0.01, 0)
# 	m = uniform(1, 0, 0)
# 	steps(3)
# 	m = uniform(1, 0, 0)
# 	t = 0
# 	start := now()
# 	neval0 := Neval.get()
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/energy_vs_L_vortex.mx3
# Out:
# --2025-10-20 14:05:42--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/energy_vs_L_vortex.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 944 [text/plain]
# Saving to: ‘energy_vs_L_vortex.mx3’
#
# energy_vs_L_vortex. 100%[===================>]     944  --.-KB/s    in 0s
#
# 2025-10-20 14:05:42 (21.8 MB/s) - ‘energy_vs_L_vortex.mx3’ saved [944/944]

# %%
# !/kaggle/working/mumax3.10/mumax3 -gpu 1 /kaggle/working/energy_vs_L_vortex.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/energy_vs_L_vortex.out/
# //starting GUI at http://127.0.0.1:35367
# N := 64
# setgridsize(N, N, N)
# Lmin := 8.0
# Lmax := 9.0
# Lstep := 0.05
# L := Lmin
# setcellsize(L/N, L/N, L/N)
# Msat = sqrt(2 / mu0)
# Aex = 1.0
# Ku1 = 0.1
# anisU = vector(1, 0, 0)
# m = vortex(1, -1)
# tableadd(E_total)
# tableaddvar(L, "L", "")
# for L = Lmin; L <= Lmax; L += Lstep {
# 	setcellsize(L/N, L/N, L/N)
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/energy_vs_L_singledomain.mx3
# Out:
# --2025-10-20 14:16:04--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/energy_vs_L_singledomain.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 960 [text/plain]
# Saving to: ‘energy_vs_L_singledomain.mx3’
#
# energy_vs_L_singled 100%[===================>]     960  --.-KB/s    in 0s
#
# 2025-10-20 14:16:04 (61.5 MB/s) - ‘energy_vs_L_singledomain.mx3’ saved [960/960]

# %%
# !/kaggle/working/mumax3.10/mumax3 -gpu 1 /kaggle/working/energy_vs_L_singledomain.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/energy_vs_L_singledomain.out/
# //starting GUI at http://127.0.0.1:35367
# N := 64
# setgridsize(N, N, N)
# Lmin := 8.0
# Lmax := 9.0
# Lstep := 0.05
# L := Lmin
# setcellsize(L/N, L/N, L/N)
# Msat = sqrt(2 / mu0)
# Aex = 1.0
# Ku1 = 0.1
# anisU = vector(1, 0, 0)
# m = uniform(1.0, 0, 0.001)
# tableadd(E_total)
# tableaddvar(L, "L", "")
# for L = Lmin; L <= Lmax; L += Lstep {
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/skyrmion_STT_dynamics.mx3
# Out:
# --2025-10-20 14:17:33--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/skyrmion_STT_dynamics.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 945 [text/plain]
# Saving to: ‘skyrmion_STT_dynamics.mx3’
#
# skyrmion_STT_dynami 100%[===================>]     945  --.-KB/s    in 0s
#
# 2025-10-20 14:17:33 (63.1 MB/s) - ‘skyrmion_STT_dynamics.mx3’ saved [945/945]

# %%
# !/kaggle/working/mumax3.10/mumax3 -gpu 1 /kaggle/working/skyrmion_STT_dynamics.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/skyrmion_STT_dynamics.out/
# //starting GUI at http://127.0.0.1:35367
# setgridsize(256, 64, 1)
# setcellsize(1e-9, 1e-9, 1e-9)
# setpbc(4, 0, 0)
# //resizing...
# // Initializing geometry 1 %
# // Initializing geometry 100 %
# Msat = 580e3
# Aex = 15e-12
# Dind = 3.0e-3
# Ku1 = 0.8e6
# AnisU = vector(0, 0, 1)
# alpha = 0.1
# m = neelskyrmion(-1, 1).transl(-40e-9, 0, 0)
# minimize()
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/permalloy_hysteresis.mx3
# Out:
# --2025-10-20 14:36:49--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/permalloy_hysteresis.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1206 (1.2K) [text/plain]
# Saving to: ‘permalloy_hysteresis.mx3’
#
# permalloy_hysteresi 100%[===================>]   1.18K  --.-KB/s    in 0s
#
# 2025-10-20 14:36:49 (61.1 MB/s) - ‘permalloy_hysteresis.mx3’ saved [1206/1206]

# %%
# !/kaggle/working/mumax3.10/mumax3 -gpu 1 /kaggle/working/permalloy_hysteresis.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.6, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: /kaggle/working/permalloy_hysteresis.out/
# //starting GUI at http://127.0.0.1:35367
# SetGridsize(192, 384, 1)
# SetCellsize(1000e-9/192, 2000e-9/384, 20e-9)
# Msat = 800e3
# Aex = 13e-12
# alpha = 0.02
# Ku1 = 5e2
# anisu = vector(0, 1, 0)
# m = uniform(-0.1, -1, 0)
# angle := pi / 180
# B_ext = vector(-0.05*sin(angle), -0.05*cos(angle), 0)
# tableadd(B_ext)
# relax()
# ...

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/complexgeometry_hysteresis.mx3
# Out:
# --2025-10-20 15:09:55--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/refs/heads/main/complexgeometry_hysteresis.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1859 (1.8K) [text/plain]
# Saving to: ‘complexgeometry_hysteresis.mx3’
#
# complexgeometry_hys 100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2025-10-20 15:09:55 (40.0 MB/s) - ‘complexgeometry_hysteresis.mx3’ saved [1859/1859]

# %%
# !wget https://raw.githubusercontent.com/mhputra94/MuMax3Learn/main/drawing.png
# Out:
# --2025-10-20 15:11:46--  https://raw.githubusercontent.com/mhputra94/MuMax3Learn/main/drawing.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3433 (3.4K) [image/png]
# Saving to: ‘drawing.png’
#
# drawing.png         100%[===================>]   3.35K  --.-KB/s    in 0s
#
# 2025-10-20 15:11:46 (46.0 MB/s) - ‘drawing.png’ saved [3433/3433]

# %%
# !/kaggle/working/mumax3.10/mumax3 -gpu 0 /kaggle/working/complexgeometry_hysteresis.mx3
